# %%
import pandas as pd
df = pd.read_excel('Book1.xlsx')

# %%
df
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %% [markdown]
# # show cell has value by false and other examle nan by false

# %%
df.isnull()
# Out:
#    Gender   Race  Birth_Year  Marital_Status  Years_on_Internet  \
# 0   False  False       False           False              False
# 1   False  False       False           False              False
# 2   False  False       False           False              False
# 3   False  False       False           False              False
# 4   False  False       False           False              False
# 5   False  False       False           False              False
# 6   False  False       False           False              False
# 7   False  False       False           False              False
# 8   False  False       False           False              False
# 9   False  False       False           False              False
#
#    Hours_Per_Day  Preferred_Browser  Preferred_Search_Engine  Preferred_Email  \
# 0          False              False                    False            False
# 1          False              False                    False            False
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
print(f'Is there any null value in dataset?? {df.isnull().values.any()}')
# Out:
# Is there any null value in dataset?? True

# %% [markdown]
# # get mode

# %%
df.mode()
# Out:
#   Gender   Race  Birth_Year Marital_Status  Years_on_Internet  Hours_Per_Day  \
# 0      M  White        1977              S                  6            2.0
# 1    NaN    NaN        1981            NaN                  8            NaN
#
#   Preferred_Browser Preferred_Search_Engine Preferred_Email Read_News  \
# 0           Firefox                  Google           Yahoo         Y
# 1               NaN                     NaN             NaN       NaN
#
#   Online_Shopping Online_Gaming Facebook Twitter Other_Social_Network
# 0               Y             N        Y       N             LinkedIn
# 1             NaN           NaN      NaN     NaN                  NaN

# %%
df
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %% [markdown]
# # show column

# %%
df['Online_Gaming']
# Out:
# 0      N
# 1      N
# 2    NaN
# 3      N
# 4      N
# 5      Y
# 6    NaN
# 7    NaN
# 8      N
# 9      Y
# Name: Online_Gaming, dtype: object

# %% [markdown]
# # change nan values >> N

# %%
df['Online_Gaming'].fillna('N', inplace = True)

# %%
df['Online_Gaming']
# Out:
# 0    N
# 1    N
# 2    N
# 3    N
# 4    N
# 5    Y
# 6    N
# 7    N
# 8    N
# 9    Y
# Name: Online_Gaming, dtype: object

# %%
df
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %% [markdown]
# # filter

# %%
df.dropna(subset = ['Other_Social_Network'], inplace = True)

# %%
df
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 6              2            Firefox                  Google           Yahoo
# 7              3  Internet Explorer                   Yahoo           Yahoo
# 9              1             Safari                   Yahoo           Yahoo
#
#   Read_News Online_Shopping Online_Gaming Facebook Twitter  \
# 6       NaN               Y             N        Y       Y
# 7         Y             NaN             N        Y      99
# 9         Y             NaN             Y        Y       N
#
#   Other_Social_Network
# 6             LinkedIn
# 7             LinkedIn
# 9              MySpace

# %%
df
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 6              2            Firefox                  Google           Yahoo
# 7              3  Internet Explorer                   Yahoo           Yahoo
# 9              1             Safari                   Yahoo           Yahoo
#
#   Read_News Online_Shopping Online_Gaming Facebook Twitter  \
# 6       NaN               Y             N        Y       Y
# 7         Y             NaN             N        Y      99
# 9         Y             NaN             Y        Y       N
#
#   Other_Social_Network
# 6             LinkedIn
# 7             LinkedIn
# 9              MySpace

# %%
df2 = pd.read_excel('Book1.xlsx')

# %%
df2
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %%
df2.dtypes
# Out:
# Gender                     object
# Race                       object
# Birth_Year                  int64
# Marital_Status             object
# Years_on_Internet           int64
# Hours_Per_Day               int64
# Preferred_Browser          object
# Preferred_Search_Engine    object
# Preferred_Email            object
# Read_News                  object
# Online_Shopping            object
# Online_Gaming              object
# Facebook                   object
# Twitter                    object
# Other_Social_Network       object
# dtype: object

# %% [markdown]
# # Get all the modes of a column

# %%
for col in df2.columns:
    print(f' {col :30s}>>>>>>>>>> {df2[col].unique()}')
# Out:
#  Gender                        >>>>>>>>>> ['M' 'F']
#  Race                          >>>>>>>>>> ['White' 'Hispanic' 'African American']
#  Birth_Year                    >>>>>>>>>> [1972 1981 1977 1961 1954 1982 1969 1987]
#  Marital_Status                >>>>>>>>>> ['M' 'S' 'D']
#  Years_on_Internet             >>>>>>>>>> [ 8 14  6  2 15 11  3 12]
#  Hours_Per_Day                 >>>>>>>>>> [1 2 6 3 4]
#  Preferred_Browser             >>>>>>>>>> ['Firefox' 'Chrome' 'Internet Explorer' 'Safari']
#  Preferred_Search_Engine       >>>>>>>>>> ['Google' 'Yahoo' 'Bing']
#  Preferred_Email               >>>>>>>>>> ['Yahoo' 'Hotmail' 'Gmail']
#  Read_News                     >>>>>>>>>> ['Y' 'N' nan]
#  Online_Shopping               >>>>>>>>>> ['N' 'Y' nan]
#  Online_Gaming                 >>>>>>>>>> ['N' nan 'Y']
#  Facebook                      >>>>>>>>>> ['Y' 'N']
#  Twitter                       >>>>>>>>>> ['N' 'Y' 99]
#  Other_Social_Network          >>>>>>>>>> [nan 'LinkedIn' 'MySpace']

# %%
df2.describe()
# Out:
#         Birth_Year  Years_on_Internet  Hours_Per_Day
# count    10.000000          10.000000      10.000000
# mean   1974.100000           8.500000       2.600000
# std      10.257247           4.428443       1.505545
# min    1954.000000           2.000000       1.000000
# 25%    1969.750000           6.000000       2.000000
# 50%    1977.000000           8.000000       2.000000
# 75%    1981.000000          11.750000       3.000000
# max    1987.000000          15.000000       6.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   10 non-null     object
#  1   Race                     10 non-null     object
#  2   Birth_Year               10 non-null     int64
#  3   Marital_Status           10 non-null     object
#  4   Years_on_Internet        10 non-null     int64
#  5   Hours_Per_Day            10 non-null     int64
#  6   Preferred_Browser        10 non-null     object
#  7   Preferred_Search_Engine  10 non-null     object
#  8   Preferred_Email          10 non-null     object
#  9   Read_News                9 non-null      object
#  10  Online_Shopping          8 non-null      object
#  11  Online_Gaming            7 non-null      object
#  12  Facebook                 10 non-null     object
#  13  Twitter                  10 non-null     object
# ...

# %%
df2
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %%
df2['Twitter'] == 99
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Twitter, dtype: bool

# %%
[df2['Twitter'] == 'Y']
# Out:
# [0    False
#  1    False
#  2    False
#  3     True
#  4    False
#  5    False
#  6     True
#  7    False
#  8    False
#  9    False
#  Name: Twitter, dtype: bool]

# %%
df2['Twitter'][df2['Twitter'] == 'Y'].index
# Out:
# Int64Index([3, 6], dtype='int64')

# %%
internet_data_set = pd.read_excel('Book1.xlsx')
internet_data_set['Twitter'].replace('99' , 'N',inplace=True)
internet_data_set
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
# 5      M  African American        1982              D                 15
# 6      M  African American        1981              D                 11
# 7      M             White        1977              S                  3
# 8      F  African American        1969              M                  6
# 9      M             White        1987              S                 12
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# ...

# %%
df2[['Twitter','Preferred_Search_Engine']]
# Out:
#   Twitter Preferred_Search_Engine
# 0       N                  Google
# 1       N                  Google
# 2       N                   Yahoo
# 3       Y                  Google
# 4       N                    Bing
# 5       N                  Google
# 6       Y                  Google
# 7      99                   Yahoo
# 8       N                  Google
# 9       N                   Yahoo
